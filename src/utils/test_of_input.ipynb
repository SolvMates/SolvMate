# %%
from input import run_Import

goal_dataframe = run_Import("/workspaces/SolvMate/input/04.32_SAS_Input_CDR.xls")
# Out:
# 2025-08-13 11:22:42,356 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.Basic+input&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# 2025-08-13 11:22:42,844 - input - WARNING - Could not convert date value for INFO_REPORT_DT: 2023-09-30 00:00:00
# 2025-08-13 11:22:42,952 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.MarketR&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# 2025-08-13 11:22:43,352 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.ConcR&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# 2025-08-13 11:22:43,712 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.CurrR&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# 2025-08-13 11:22:44,115 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.CDR&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# 2025-08-13 11:22:49,371 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.net+Prem+CP&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# 2025-08-13 11:22:51,373 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.LnH+SLT+UW&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# 2025-08-13 11:22:51,718 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.Health+cat&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# /workspaces/SolvMate/src/utils/input.py:277: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_id_table_enriched = pd.concat(
# 2025-08-13 11:22:53,549 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.NL+NatCat&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# /workspaces/SolvMate/src/utils/input.py:277: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_id_table_enriched = pd.concat(
# 2025-08-13 11:23:04,591 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.NatC+OthR&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# /workspaces/SolvMate/src/utils/input.py:277: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_id_table_enriched = pd.concat(
# 2025-08-13 11:23:04,966 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.NL+man-made&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# 2025-08-13 11:23:05,440 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.OpRisk&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# 2025-08-13 11:23:05,776 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.MCR&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# 2025-08-13 11:23:06,101 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.Simplifications&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# 2025-08-13 11:23:06,617 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/data_id?select=%2A&WORKSHEET=eq.CDR+-+SCR+hyp&MODULE=neq.Counterparty+Simplified "HTTP/2 200 OK"
# CDR - SCR hyp: 43 counterparties with RM flag but no RM effect found. Using limit 43.
# /workspaces/SolvMate/src/utils/input.py:277: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_id_table_enriched = pd.concat(
# 2025-08-13 11:23:18,124 - httpx - INFO - HTTP Request: GET https://hgdgxwrwohwkmywruxat.supabase.co/rest/v1/map_hyp_scr?select=%2A "HTTP/2 200 OK"
